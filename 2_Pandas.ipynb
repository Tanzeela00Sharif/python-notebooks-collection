# %% [markdown]
# <a href="https://colab.research.google.com/github/Tanzeela00Sharif/python-notebooks-collection/blob/main/2_Pandas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Dataframes in pandas

# %% [markdown]
# 2D data is called dataframes. tables in pandas are dataframes.

# %%
import numpy as np
import pandas as pd

# %% [markdown]
# ##creating dataframes

# %%
#from lists
student_list=[
    [100,12,19,0,0],
    [34,10,15,0,0],
    [56,5,16,0,0]
    ]

student=pd.DataFrame(student_list, columns=['iq','experience','salerypakage','nullcolumn','null'])

# %%
#from dictionary

student_dict={
    'name':['tanzila','amna','ayesha','hamna','ali'],
    'iq':[100,12,19,0,0],
    'experience':[12,10,5,0,0],
    'salery pakage':[12,17,89,0,0]

}
student_info=pd.DataFrame(student_dict)
student_info.set_index('name',inplace=True)

# %%
movies=pd.read_csv('/content/movies.csv')
movies
# Out:
#                                    title_x     imdb_id  \
# 0                 Uri: The Surgical Strike   tt8291224
# 1                            Battalion 609   tt9472208
# 2     The Accidental Prime Minister (film)   tt6986710
# 3                          Why Cheat India   tt8108208
# 4                          Evening Shadows   tt6028796
# ...                                    ...         ...
# 1624                 Tera Mera Saath Rahen   tt0301250
# 1625                  Yeh Zindagi Ka Safar   tt0298607
# 1626                       Sabse Bada Sukh   tt0069204
# 1627                                 Daaka  tt10833860
# 1628                              Humsafar   tt2403201
#
#                                             poster_path  \
# 0     https://upload.wikimedia.org/wikipedia/en/thum...
# 1                                                   NaN
# 2     https://upload.wikimedia.org/wikipedia/en/thum...
# 3     https://upload.wikimedia.org/wikipedia/en/thum...
# ...

# %%
ipl=pd.read_csv('/content/ipl-matches.csv')
ipl
# Out:
#           ID        City        Date   Season  MatchNumber  \
# 0    1312200   Ahmedabad  2022-05-29     2022        Final
# 1    1312199   Ahmedabad  2022-05-27     2022  Qualifier 2
# 2    1312198     Kolkata  2022-05-25     2022   Eliminator
# 3    1312197     Kolkata  2022-05-24     2022  Qualifier 1
# 4    1304116      Mumbai  2022-05-22     2022           70
# ..       ...         ...         ...      ...          ...
# 945   335986     Kolkata  2008-04-20  2007/08            4
# 946   335985      Mumbai  2008-04-20  2007/08            5
# 947   335984       Delhi  2008-04-19  2007/08            3
# 948   335983  Chandigarh  2008-04-19  2007/08            2
# 949   335982   Bangalore  2008-04-18  2007/08            1
#
#                            Team1                        Team2  \
# 0               Rajasthan Royals               Gujarat Titans
# 1    Royal Challengers Bangalore             Rajasthan Royals
# 2    Royal Challengers Bangalore         Lucknow Super Giants
# ...

# %%
ipl.head(1)
# Out:
#         ID       City        Date Season MatchNumber             Team1  \
# 0  1312200  Ahmedabad  2022-05-29   2022       Final  Rajasthan Royals
#
#             Team2                             Venue        TossWinner  \
# 0  Gujarat Titans  Narendra Modi Stadium, Ahmedabad  Rajasthan Royals
#
#   TossDecision SuperOver     WinningTeam    WonBy  Margin method  \
# 0          bat         N  Gujarat Titans  Wickets     7.0    NaN
#
#   Player_of_Match                                       Team1Players  \
# 0       HH Pandya  ['YBK Jaiswal', 'JC Buttler', 'SV Samson', 'D ...
#
#                                         Team2Players      Umpire1      Umpire2
# 0  ['WP Saha', 'Shubman Gill', 'MS Wade', 'HH Pan...  CB Gaffaney  Nitin Menon

# %%
#movie data shape
print(movies.shape)
print(ipl.shape)
# Out:
# (1629, 18)
# (950, 20)

# %%
movies.dtypes
# Out:
# title_x              object
# imdb_id              object
# poster_path          object
# wiki_link            object
# title_y              object
# original_title       object
# is_adult              int64
# year_of_release       int64
# runtime              object
# genres               object
# imdb_rating         float64
# imdb_votes            int64
# story                object
# summary              object
# tagline              object
# actors               object
# wins_nominations     object
# release_date         object
# dtype: object

# %%
#dtypes
ipl.dtypes
# Out:
# ID                   int64
# City                object
# Date                object
# Season              object
# MatchNumber         object
# Team1               object
# Team2               object
# Venue               object
# TossWinner          object
# TossDecision        object
# SuperOver           object
# WinningTeam         object
# WonBy               object
# Margin             float64
# method              object
# Player_of_Match     object
# Team1Players        object
# Team2Players        object
# Umpire1             object
# Umpire2             object
# dtype: object

# %%
movies.index
ipl.index
# Out:
# RangeIndex(start=0, stop=950, step=1)

# %%
movies.columns
# Out:
# Index(['title_x', 'imdb_id', 'poster_path', 'wiki_link', 'title_y',
#        'original_title', 'is_adult', 'year_of_release', 'runtime', 'genres',
#        'imdb_rating', 'imdb_votes', 'story', 'summary', 'tagline', 'actors',
#        'wins_nominations', 'release_date'],
#       dtype='object')

# %%
ipl.columns
# Out:
# Index(['ID', 'City', 'Date', 'Season', 'MatchNumber', 'Team1', 'Team2',
#        'Venue', 'TossWinner', 'TossDecision', 'SuperOver', 'WinningTeam',
#        'WonBy', 'Margin', 'method', 'Player_of_Match', 'Team1Players',
#        'Team2Players', 'Umpire1', 'Umpire2'],
#       dtype='object')

# %%
student.columns
# Out:
# Index(['iq', 'experience', 'salerypakage', 'nullcolumn', 'null'], dtype='object')

# %%
student_info.columns
# Out:
# Index(['iq', 'experience', 'salery pakage'], dtype='object')

# %%
student.values
# Out:
# array([[100,  12,  19,   0,   0],
#        [ 34,  10,  15,   0,   0],
#        [ 56,   5,  16,   0,   0]])

# %%
movies.values
# Out:
# array([['Uri: The Surgical Strike', 'tt8291224',
#         'https://upload.wikimedia.org/wikipedia/en/thumb/3/3b/URI_-_New_poster.jpg/220px-URI_-_New_poster.jpg',
#         ...,
#         'Vicky Kaushal|Paresh Rawal|Mohit Raina|Yami Gautam|Kirti Kulhari|Rajit Kapoor|Ivan Rodrigues|Manasi Parekh|Swaroop Sampat|Riva Arora|Yogesh Soman|Fareed Ahmed|Akashdeep Arora|Kallol Banerjee|',
#         '4 wins', '11 January 2019 (USA)'],
#        ['Battalion 609', 'tt9472208', nan, ...,
#         'Vicky Ahuja|Shoaib Ibrahim|Shrikant Kamat|Elena Kazan|Vishwas Kini|Major Kishore|Jashn Kohli|Rammy C. Pandey|Manish Sharma|Sparsh Sharma|Farnaz Shetty|Vikas Shrivastav|Chandraprakash Thakur|Brajesh Tiwari|',
#         nan, '11 January 2019 (India)'],
#        ['The Accidental Prime Minister (film)', 'tt6986710',
#         'https://upload.wikimedia.org/wikipedia/en/thumb/a/a1/The_Accidental_Prime_Minister_film.jpg/220px-The_Accidental_Prime_Minister_film.jpg',
#         ...,
# ...

# %%
movies.head(5)
# Out:
#                                 title_x    imdb_id  \
# 0              Uri: The Surgical Strike  tt8291224
# 1                         Battalion 609  tt9472208
# 2  The Accidental Prime Minister (film)  tt6986710
# 3                       Why Cheat India  tt8108208
# 4                       Evening Shadows  tt6028796
#
#                                          poster_path  \
# 0  https://upload.wikimedia.org/wikipedia/en/thum...
# 1                                                NaN
# 2  https://upload.wikimedia.org/wikipedia/en/thum...
# 3  https://upload.wikimedia.org/wikipedia/en/thum...
# 4                                                NaN
#
#                                            wiki_link  \
# 0  https://en.wikipedia.org/wiki/Uri:_The_Surgica...
# 1        https://en.wikipedia.org/wiki/Battalion_609
# 2  https://en.wikipedia.org/wiki/The_Accidental_P...
# 3      https://en.wikipedia.org/wiki/Why_Cheat_India
# 4      https://en.wikipedia.org/wiki/Evening_Shadows
#
# ...

# %%
ipl.tail(3)
# Out:
#          ID        City        Date   Season MatchNumber  \
# 947  335984       Delhi  2008-04-19  2007/08           3
# 948  335983  Chandigarh  2008-04-19  2007/08           2
# 949  335982   Bangalore  2008-04-18  2007/08           1
#
#                            Team1                  Team2  \
# 947             Delhi Daredevils       Rajasthan Royals
# 948              Kings XI Punjab    Chennai Super Kings
# 949  Royal Challengers Bangalore  Kolkata Knight Riders
#
#                                           Venue                   TossWinner  \
# 947                            Feroz Shah Kotla             Rajasthan Royals
# 948  Punjab Cricket Association Stadium, Mohali          Chennai Super Kings
# 949                       M Chinnaswamy Stadium  Royal Challengers Bangalore
#
#     TossDecision SuperOver            WinningTeam    WonBy  Margin method  \
# 947          bat         N       Delhi Daredevils  Wickets     9.0    NaN
# ...

# %%
movies.sample(5)
# Out:
#                             title_x    imdb_id  \
# 915              Wanted (2009 film)  tt1084972
# 42                      Batla House  tt8869978
# 1374  Police Force: An Inside Story  tt0416120
# 602                   Zindagi 50-50  tt2929840
# 1387           Shart: The Challenge  tt0410591
#
#                                             poster_path  \
# 915   https://upload.wikimedia.org/wikipedia/en/thum...
# 42    https://upload.wikimedia.org/wikipedia/en/e/ed...
# 1374  https://upload.wikimedia.org/wikipedia/en/thum...
# 602   https://upload.wikimedia.org/wikipedia/en/thum...
# 1387  https://upload.wikimedia.org/wikipedia/en/thum...
#
#                                               wiki_link  \
# 915    https://en.wikipedia.org/wiki/Wanted_(2009_film)
# 42            https://en.wikipedia.org/wiki/Batla_House
# 1374  https://en.wikipedia.org/wiki/Police_Force:_An...
# 602         https://en.wikipedia.org/wiki/Zindagi_50-50
# ...

# %%
movies.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1629 entries, 0 to 1628
# Data columns (total 18 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   title_x           1629 non-null   object
#  1   imdb_id           1629 non-null   object
#  2   poster_path       1526 non-null   object
#  3   wiki_link         1629 non-null   object
#  4   title_y           1629 non-null   object
#  5   original_title    1629 non-null   object
#  6   is_adult          1629 non-null   int64
#  7   year_of_release   1629 non-null   int64
#  8   runtime           1629 non-null   object
#  9   genres            1629 non-null   object
#  10  imdb_rating       1629 non-null   float64
#  11  imdb_votes        1629 non-null   int64
#  12  story             1609 non-null   object
#  13  summary           1629 non-null   object
#  14  tagline           557 non-null    object
#  15  actors            1624 non-null   object
# ...

# %%
ipl.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 950 entries, 0 to 949
# Data columns (total 20 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   ID               950 non-null    int64
#  1   City             899 non-null    object
#  2   Date             950 non-null    object
#  3   Season           950 non-null    object
#  4   MatchNumber      950 non-null    object
#  5   Team1            950 non-null    object
#  6   Team2            950 non-null    object
#  7   Venue            950 non-null    object
#  8   TossWinner       950 non-null    object
#  9   TossDecision     950 non-null    object
#  10  SuperOver        946 non-null    object
#  11  WinningTeam      946 non-null    object
#  12  WonBy            950 non-null    object
#  13  Margin           932 non-null    float64
#  14  method           19 non-null     object
#  15  Player_of_Match  946 non-null    object
# ...

# %%
#work on numeric values
movies.describe()
# Out:
#        is_adult  year_of_release  imdb_rating     imdb_votes
# count    1629.0      1629.000000  1629.000000    1629.000000
# mean        0.0      2010.263966     5.557459    5384.263352
# std         0.0         5.381542     1.567609   14552.103231
# min         0.0      2001.000000     0.000000       0.000000
# 25%         0.0      2005.000000     4.400000     233.000000
# 50%         0.0      2011.000000     5.600000    1000.000000
# 75%         0.0      2015.000000     6.800000    4287.000000
# max         0.0      2019.000000     9.400000  310481.000000

# %%
ipl.describe()
# Out:
#                  ID      Margin
# count  9.500000e+02  932.000000
# mean   8.304852e+05   17.056867
# std    3.375678e+05   21.633109
# min    3.359820e+05    1.000000
# 25%    5.012612e+05    6.000000
# 50%    8.297380e+05    8.000000
# 75%    1.175372e+06   19.000000
# max    1.312200e+06  146.000000

# %%
#use to see the missing values
movies.isnull().sum()
# Out:
# title_x                0
# imdb_id                0
# poster_path          103
# wiki_link              0
# title_y                0
# original_title         0
# is_adult               0
# year_of_release        0
# runtime                0
# genres                 0
# imdb_rating            0
# imdb_votes             0
# story                 20
# summary                0
# tagline             1072
# actors                 5
# wins_nominations     922
# release_date         107
# dtype: int64

# %%
movies.duplicated().sum()
# Out:
# np.int64(0)

# %%
student.duplicated().sum()
# Out:
# np.int64(0)

# %%
student_info.duplicated()
# Out:
# name
# tanzila    False
# amna       False
# ayesha     False
# hamna      False
# ali         True
# dtype: bool

# %%
#rename
student.columns
# Out:
# Index(['iq', 'experience', 'salerypakage', 'nullcolumn', 'null'], dtype='object')

# %%
#rename does not create the permanant changes in the data set
student.rename(columns={'experience':'years of experience','nullcolumn':'diability'})
# Out:
#     iq  years of experience  salerypakage  diability  null
# 0  100                   12            19          0     0
# 1   34                   10            15          0     0
# 2   56                    5            16          0     0

# %%
student
# Out:
#     iq  experience  salerypakage  nullcolumn  null
# 0  100          12            19           0     0
# 1   34          10            15           0     0
# 2   56           5            16           0     0

# %%
#by using inpalce we can create the permanant changes within the data set
student.rename(columns={'experience':'years of experience','nullcolumn':'diability'},inplace=True)

# %%
student
# Out:
#     iq  years of experience  salerypakage  diability  null
# 0  100                   12            19          0     0
# 1   34                   10            15          0     0
# 2   56                    5            16          0     0

# %% [markdown]
# ## Math function in dataframes

# %%
#sun function inndataframes apply on the numeric columns while in string columns it concatenate the strings
#colunsise sum
student.sum()
# Out:
# iq                     190
# years of experience     27
# salerypakage            50
# diability                0
# null                     0
# dtype: int64

# %%
#row wise sum
student.sum(axis=1)
# Out:
# 0    131
# 1     59
# 2     77
# dtype: int64

# %%
student.mean()
# Out:
# iq                     63.333333
# years of experience     9.000000
# salerypakage           16.666667
# diability               0.000000
# null                    0.000000
# dtype: float64

# %%
student.median ()
# Out:
# iq                     56.0
# years of experience    10.0
# salerypakage           16.0
# diability               0.0
# null                    0.0
# dtype: float64

# %%
movies.columns
# Out:
# Index(['title_x', 'imdb_id', 'poster_path', 'wiki_link', 'title_y',
#        'original_title', 'is_adult', 'year_of_release', 'runtime', 'genres',
#        'imdb_rating', 'imdb_votes', 'story', 'summary', 'tagline', 'actors',
#        'wins_nominations', 'release_date'],
#       dtype='object')

# %%
#fetch single column
movies['title_x']
# Out:
# 0                   Uri: The Surgical Strike
# 1                              Battalion 609
# 2       The Accidental Prime Minister (film)
# 3                            Why Cheat India
# 4                            Evening Shadows
#                         ...
# 1624                   Tera Mera Saath Rahen
# 1625                    Yeh Zindagi Ka Safar
# 1626                         Sabse Bada Sukh
# 1627                                   Daaka
# 1628                                Humsafar
# Name: title_x, Length: 1629, dtype: object

# %%
ipl.columns
# Out:
# Index(['ID', 'City', 'Date', 'Season', 'MatchNumber', 'Team1', 'Team2',
#        'Venue', 'TossWinner', 'TossDecision', 'SuperOver', 'WinningTeam',
#        'WonBy', 'Margin', 'method', 'Player_of_Match', 'Team1Players',
#        'Team2Players', 'Umpire1', 'Umpire2'],
#       dtype='object')

# %%
#single column extracted from the table or dataframe is series
type(ipl['Venue'])
# Out:
# pandas.core.series.Series

# %%
#fency indexing
#fetch many columns randomly
movies[['actors','year_of_release','imdb_rating']]
# Out:
#                                                  actors  year_of_release  \
# 0     Vicky Kaushal|Paresh Rawal|Mohit Raina|Yami Ga...             2019
# 1     Vicky Ahuja|Shoaib Ibrahim|Shrikant Kamat|Elen...             2019
# 2     Anupam Kher|Akshaye Khanna|Aahana Kumra|Atul S...             2019
# 3     Emraan Hashmi|Shreya Dhanwanthary|Snighdadeep ...             2019
# 4     Mona Ambegaonkar|Ananth Narayan Mahadevan|Deva...             2018
# ...                                                 ...              ...
# 1624  Ajay Devgn|Sonali Bendre|Namrata Shirodkar|Pre...             2001
# 1625  Ameesha Patel|Jimmy Sheirgill|Nafisa Ali|Gulsh...             2001
# 1626  Vijay Arora|Asrani|Rajni Bala|Kumud Damle|Utpa...             2018
# 1627                          Gippy Grewal|Zareen Khan|             2019
# 1628                                        Fawad Khan|             2011
#
#       imdb_rating
# 0             8.4
# 1             4.1
# 2             6.1
# ...

# %%
#when multiple columns fetch from the dataframe , this also tha mini dataframe
type(movies[['actors','year_of_release','imdb_rating']])
# Out:
# pandas.core.frame.DataFrame

# %%
ipl[['Venue','Team1', 'Team2']]
# Out:
#                                           Venue                        Team1  \
# 0              Narendra Modi Stadium, Ahmedabad             Rajasthan Royals
# 1              Narendra Modi Stadium, Ahmedabad  Royal Challengers Bangalore
# 2                         Eden Gardens, Kolkata  Royal Challengers Bangalore
# 3                         Eden Gardens, Kolkata             Rajasthan Royals
# 4                      Wankhede Stadium, Mumbai          Sunrisers Hyderabad
# ..                                          ...                          ...
# 945                                Eden Gardens        Kolkata Knight Riders
# 946                            Wankhede Stadium               Mumbai Indians
# 947                            Feroz Shah Kotla             Delhi Daredevils
# 948  Punjab Cricket Association Stadium, Mohali              Kings XI Punjab
# 949                       M Chinnaswamy Stadium  Royal Challengers Bangalore
#
#                            Team2
# ...

# %% [markdown]
# ##fetch rows from the dataframe

# %% [markdown]
# ###selecting rows from dataframe use two methods
#
#
#
# *   iloc -> seraching using index position
# iloc is used when we used the index provided by the python
#
#
# *   loc -> searches use index lables
# loc is used when we used the index provided by us

# %%
student_info
# Out:
#           iq  experience  salery pakage
# name
# tanzila  100          12             12
# amna      12          10             17
# ayesha    19           5             89
# hamna      0           0              0
# ali        0           0              0

# %%
#single row
#it extrac the data of single movie
movies.iloc[0]
# Out:
# title_x                                      Uri: The Surgical Strike
# imdb_id                                                     tt8291224
# poster_path         https://upload.wikimedia.org/wikipedia/en/thum...
# wiki_link           https://en.wikipedia.org/wiki/Uri:_The_Surgica...
# title_y                                      Uri: The Surgical Strike
# original_title                               Uri: The Surgical Strike
# is_adult                                                            0
# year_of_release                                                  2019
# runtime                                                           138
# genres                                               Action|Drama|War
# imdb_rating                                                       8.4
# imdb_votes                                                      35112
# story               Divided over five chapters  the film chronicle...
# ...

# %%
type(ipl.iloc[1])
# Out:
# pandas.core.series.Series

# %%
#fetch multiple rows
movies.iloc[0:5]
# Out:
#                                 title_x    imdb_id  \
# 0              Uri: The Surgical Strike  tt8291224
# 1                         Battalion 609  tt9472208
# 2  The Accidental Prime Minister (film)  tt6986710
# 3                       Why Cheat India  tt8108208
# 4                       Evening Shadows  tt6028796
#
#                                          poster_path  \
# 0  https://upload.wikimedia.org/wikipedia/en/thum...
# 1                                                NaN
# 2  https://upload.wikimedia.org/wikipedia/en/thum...
# 3  https://upload.wikimedia.org/wikipedia/en/thum...
# 4                                                NaN
#
#                                            wiki_link  \
# 0  https://en.wikipedia.org/wiki/Uri:_The_Surgica...
# 1        https://en.wikipedia.org/wiki/Battalion_609
# 2  https://en.wikipedia.org/wiki/The_Accidental_P...
# 3      https://en.wikipedia.org/wiki/Why_Cheat_India
# 4      https://en.wikipedia.org/wiki/Evening_Shadows
#
# ...

# %%
#fency indexing
#extract rows without any patterns

movies.iloc[[2,4,16,7]]
# Out:
#                                  title_x    imdb_id  \
# 2   The Accidental Prime Minister (film)  tt6986710
# 4                        Evening Shadows  tt6028796
# 16                Mard Ko Dard Nahi Hota  tt8055888
# 7                             Bombairiya  tt4971258
#
#                                           poster_path  \
# 2   https://upload.wikimedia.org/wikipedia/en/thum...
# 4                                                 NaN
# 16  https://upload.wikimedia.org/wikipedia/en/thum...
# 7   https://upload.wikimedia.org/wikipedia/en/thum...
#
#                                             wiki_link  \
# 2   https://en.wikipedia.org/wiki/The_Accidental_P...
# 4       https://en.wikipedia.org/wiki/Evening_Shadows
# 16  https://en.wikipedia.org/wiki/Mard_Ko_Dard_Nah...
# 7            https://en.wikipedia.org/wiki/Bombairiya
#
#                           title_y                 original_title  is_adult  \
# ...

# %%
student_info
# Out:
#           iq  experience  salery pakage
# name
# tanzila  100          12             12
# amna      12          10             17
# ayesha    19           5             89
# hamna      0           0              0
# ali        0           0              0

# %%
#by using lables of the row
student_info.loc['tanzila']
# Out:
# iq               100
# experience        12
# salery pakage     12
# Name: tanzila, dtype: int64

# %%
student_info.loc['ali']
# Out:
# iq               0
# experience       0
# salery pakage    0
# Name: ali, dtype: int64

# %%
#slicing
student_info.loc['tanzila':'ali':2]
# Out:
#           iq  experience  salery pakage
# name
# tanzila  100          12             12
# ayesha    19           5             89
# ali        0           0              0

# %%
#fency indexing
student_info.loc[['tanzila','hamna','amna']]
# Out:
#           iq  experience  salery pakage
# name
# tanzila  100          12             12
# hamna      0           0              0
# amna      12          10             17

# %% [markdown]
# ##Filtering the dataframes

# %%
ipl
# Out:
#           ID        City        Date   Season  MatchNumber  \
# 0    1312200   Ahmedabad  2022-05-29     2022        Final
# 1    1312199   Ahmedabad  2022-05-27     2022  Qualifier 2
# 2    1312198     Kolkata  2022-05-25     2022   Eliminator
# 3    1312197     Kolkata  2022-05-24     2022  Qualifier 1
# 4    1304116      Mumbai  2022-05-22     2022           70
# ..       ...         ...         ...      ...          ...
# 945   335986     Kolkata  2008-04-20  2007/08            4
# 946   335985      Mumbai  2008-04-20  2007/08            5
# 947   335984       Delhi  2008-04-19  2007/08            3
# 948   335983  Chandigarh  2008-04-19  2007/08            2
# 949   335982   Bangalore  2008-04-18  2007/08            1
#
#                            Team1                        Team2  \
# 0               Rajasthan Royals               Gujarat Titans
# 1    Royal Challengers Bangalore             Rajasthan Royals
# 2    Royal Challengers Bangalore         Lucknow Super Giants
# ...

# %%
##find all the final winner
final=ipl[ipl['MatchNumber']=='Final']
final[['Season','WinningTeam']]
# Out:
#       Season            WinningTeam
# 0       2022         Gujarat Titans
# 74      2021    Chennai Super Kings
# 134  2020/21         Mumbai Indians
# 194     2019         Mumbai Indians
# 254     2018    Chennai Super Kings
# 314     2017         Mumbai Indians
# 373     2016    Sunrisers Hyderabad
# 433     2015         Mumbai Indians
# 492     2014  Kolkata Knight Riders
# 552     2013         Mumbai Indians
# 628     2012  Kolkata Knight Riders
# 702     2011    Chennai Super Kings
# 775  2009/10    Chennai Super Kings
# 835     2009        Deccan Chargers
# 892  2007/08       Rajasthan Royals

# %%
##how many matches own in kolkata
ipl[(ipl['City']=='Kolkata')& (ipl['WinningTeam']=='Chennai Super Kings')].shape[0]
# Out:
# 5

# %%
#how many super over finishes occour
super_over=ipl[ipl['SuperOver']=='Y']
super_over.shape[0]
# Out:
# 14

# %%
ipl.shape
# Out:
# (950, 20)

# %%
#toss winner to mach winner in percentage
ipl[ipl['TossWinner']==ipl['WinningTeam']].shape[0]/ipl.shape[0] *100
# Out:
# 51.473684210526315

# %%
#movies with rating higher than 8 and votes>10000
movies[(movies['imdb_rating'] >8) &(movies['imdb_votes'] >10000)]
# Out:
#                           title_x     imdb_id  \
# 0        Uri: The Surgical Strike   tt8291224
# 11                      Gully Boy   tt2395469
# 37              Article 15 (film)  tt10324144
# 40                Super 30 (film)   tt7485048
# 143                       Tumbbad   tt8239946
# 146                     Andhadhun   tt8108198
# 325              Pink (2016 film)   tt5571734
# 354                 Dangal (film)   tt5074352
# 418                        Masaan   tt4635372
# 426          Drishyam (2015 film)   tt4430212
# 436                 Talvar (film)   tt4934950
# 469             Queen (2014 film)   tt3322420
# 536                 Haider (film)   tt3390572
# 566                   Ugly (film)   tt2882328
# 567                     PK (film)   tt2338151
# 589                  Vishwaroopam   tt2199711
# 612            Bhaag Milkha Bhaag   tt2356180
# 638                 Shahid (film)   tt2181831
# 668       Paan Singh Tomar (film)   tt1620933
# ...

# %%
##action movies with rating higher than 7.5
movies[(movies['genres'] =='Action') &(movies['imdb_rating'] > 7.5)]
# Out:
# Empty DataFrame
# Columns: [title_x, imdb_id, poster_path, wiki_link, title_y, original_title, is_adult, year_of_release, runtime, genres, imdb_rating, imdb_votes, story, summary, tagline, actors, wins_nominations, release_date]
# Index: []

# %%
mask1= movies['genres'].str.split('|').apply(lambda x:'Action' in x)
mask2= movies['imdb_rating']>7.5
movies[mask1 & mask2]
# Out:
#                             title_x    imdb_id  \
# 0          Uri: The Surgical Strike  tt8291224
# 41             Family of Thakurganj  tt8897986
# 84                        Mukkabaaz  tt7180544
# 106                           Raazi  tt7098658
# 110   Parmanu: The Story of Pokhran  tt6826438
# 112         Bhavesh Joshi Superhero  tt6129302
# 169                The Ghazi Attack  tt6299040
# 219                Raag Desh (film)  tt6080746
# 258                   Irudhi Suttru  tt5310090
# 280                       Laal Rang  tt5600714
# 297                     Udta Punjab  tt4434004
# 354                   Dangal (film)  tt5074352
# 362               Bajrangi Bhaijaan  tt3863552
# 365          Baby (2015 Hindi film)  tt3848892
# 393      Detective Byomkesh Bakshy!  tt3447364
# 449               Titli (2014 film)  tt3019620
# 536                   Haider (film)  tt3390572
# 589                    Vishwaroopam  tt2199711
# 625                     Madras Cafe  tt2855648
# ...

# %%
ipl.head(2)
# Out:
#         ID       City        Date Season  MatchNumber  \
# 0  1312200  Ahmedabad  2022-05-29   2022        Final
# 1  1312199  Ahmedabad  2022-05-27   2022  Qualifier 2
#
#                          Team1             Team2  \
# 0             Rajasthan Royals    Gujarat Titans
# 1  Royal Challengers Bangalore  Rajasthan Royals
#
#                               Venue        TossWinner TossDecision SuperOver  \
# 0  Narendra Modi Stadium, Ahmedabad  Rajasthan Royals          bat         N
# 1  Narendra Modi Stadium, Ahmedabad  Rajasthan Royals        field         N
#
#         WinningTeam    WonBy  Margin method Player_of_Match  \
# 0    Gujarat Titans  Wickets     7.0    NaN       HH Pandya
# 1  Rajasthan Royals  Wickets     7.0    NaN      JC Buttler
#
#                                         Team1Players  \
# 0  ['YBK Jaiswal', 'JC Buttler', 'SV Samson', 'D ...
# 1  ['V Kohli', 'F du Plessis', 'RM Patidar', 'GJ ...
#
# ...

# %%
#write the function that can be return the track of 3 teams against each other
#def team('team1,team2'):
# Out:
#   File "/tmp/ipykernel_10267/2088993586.py", line 2
#     def team('team1,team2'):
#              ^
# SyntaxError: invalid syntax

# %% [markdown]
# #Adding new columns into the existing dataset

# %%
movies.columns
# Out:
# Index(['title_x', 'imdb_id', 'poster_path', 'wiki_link', 'title_y',
#        'original_title', 'is_adult', 'year_of_release', 'runtime', 'genres',
#        'imdb_rating', 'imdb_votes', 'story', 'summary', 'tagline', 'actors',
#        'wins_nominations', 'release_date'],
#       dtype='object')

# %%
movies['Country'] ='india'

# %%
movies
# Out:
#                                    title_x     imdb_id  \
# 0                 Uri: The Surgical Strike   tt8291224
# 1                            Battalion 609   tt9472208
# 2     The Accidental Prime Minister (film)   tt6986710
# 3                          Why Cheat India   tt8108208
# 4                          Evening Shadows   tt6028796
# ...                                    ...         ...
# 1624                 Tera Mera Saath Rahen   tt0301250
# 1625                  Yeh Zindagi Ka Safar   tt0298607
# 1626                       Sabse Bada Sukh   tt0069204
# 1627                                 Daaka  tt10833860
# 1628                              Humsafar   tt2403201
#
#                                             poster_path  \
# 0     https://upload.wikimedia.org/wikipedia/en/thum...
# 1                                                   NaN
# 2     https://upload.wikimedia.org/wikipedia/en/thum...
# 3     https://upload.wikimedia.org/wikipedia/en/thum...
# ...

# %% [markdown]
# ###making new column by usinfg existing dataset

# %%
movies.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1629 entries, 0 to 1628
# Data columns (total 19 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   title_x           1629 non-null   object
#  1   imdb_id           1629 non-null   object
#  2   poster_path       1526 non-null   object
#  3   wiki_link         1629 non-null   object
#  4   title_y           1629 non-null   object
#  5   original_title    1629 non-null   object
#  6   is_adult          1629 non-null   int64
#  7   year_of_release   1629 non-null   int64
#  8   runtime           1629 non-null   object
#  9   genres            1629 non-null   object
#  10  imdb_rating       1629 non-null   float64
#  11  imdb_votes        1629 non-null   int64
#  12  story             1609 non-null   object
#  13  summary           1629 non-null   object
#  14  tagline           557 non-null    object
#  15  actors            1624 non-null   object
# ...

# %%
movies.dropna(inplace=True)

# %%
movies.isnull().sum()
# Out:
# title_x             0
# imdb_id             0
# poster_path         0
# wiki_link           0
# title_y             0
# original_title      0
# is_adult            0
# year_of_release     0
# runtime             0
# genres              0
# imdb_rating         0
# imdb_votes          0
# story               0
# summary             0
# tagline             0
# actors              0
# wins_nominations    0
# release_date        0
# Country             0
# dtype: int64

# %%
movies['lead actors']=movies['actors'].str.split('|').apply(lambda x:x[0])

# %%
movies
# Out:
#                       title_x     imdb_id  \
# 11                  Gully Boy   tt2395469
# 34              Yeh Hai India   tt5525846
# 37          Article 15 (film)  tt10324144
# 87                    Aiyaary   tt6774212
# 96           Raid (2018 film)   tt7363076
# ...                       ...         ...
# 1600                   Kasoor   tt0272688
# 1601         Maya (2001 film)   tt0299027
# 1607  Nayak (2001 Hindi film)   tt0291376
# 1621                  Tum Bin   tt0290326
# 1623                 Zubeidaa   tt0255713
#
#                                             poster_path  \
# 11    https://upload.wikimedia.org/wikipedia/en/thum...
# 34    https://upload.wikimedia.org/wikipedia/en/thum...
# 37    https://upload.wikimedia.org/wikipedia/en/thum...
# 87    https://upload.wikimedia.org/wikipedia/en/thum...
# 96    https://upload.wikimedia.org/wikipedia/en/thum...
# ...                                                 ...
# 1600  https://upload.wikimedia.org/wikipedia/en/thum...
# ...

# %% [markdown]
# ###important dataframe function

# %%
#astype
ipl.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 950 entries, 0 to 949
# Data columns (total 20 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   ID               950 non-null    int64
#  1   City             899 non-null    object
#  2   Date             950 non-null    object
#  3   Season           950 non-null    object
#  4   MatchNumber      950 non-null    object
#  5   Team1            950 non-null    object
#  6   Team2            950 non-null    object
#  7   Venue            950 non-null    object
#  8   TossWinner       950 non-null    object
#  9   TossDecision     950 non-null    object
#  10  SuperOver        946 non-null    object
#  11  WinningTeam      946 non-null    object
#  12  WonBy            950 non-null    object
#  13  Margin           932 non-null    float64
#  14  method           19 non-null     object
#  15  Player_of_Match  946 non-null    object
# ...

# %%
ipl['ID']=ipl['ID'].astype('int32')

# %%
ipl.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 950 entries, 0 to 949
# Data columns (total 20 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   ID               950 non-null    int32
#  1   City             899 non-null    object
#  2   Date             950 non-null    object
#  3   Season           950 non-null    object
#  4   MatchNumber      950 non-null    object
#  5   Team1            950 non-null    object
#  6   Team2            950 non-null    object
#  7   Venue            950 non-null    object
#  8   TossWinner       950 non-null    object
#  9   TossDecision     950 non-null    object
#  10  SuperOver        946 non-null    object
#  11  WinningTeam      946 non-null    object
#  12  WonBy            950 non-null    object
#  13  Margin           932 non-null    float64
#  14  method           19 non-null     object
#  15  Player_of_Match  946 non-null    object
# ...

# %%
ipl['Team1']=ipl['Team1'].astype('category')

# %%
ipl['Team2']=ipl['Team2'].astype('category')

# %%
ipl.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 950 entries, 0 to 949
# Data columns (total 20 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   ID               950 non-null    int32
#  1   City             899 non-null    object
#  2   Date             950 non-null    object
#  3   Season           950 non-null    object
#  4   MatchNumber      950 non-null    object
#  5   Team1            950 non-null    category
#  6   Team2            950 non-null    category
#  7   Venue            950 non-null    object
#  8   TossWinner       950 non-null    object
#  9   TossDecision     950 non-null    object
#  10  SuperOver        946 non-null    object
#  11  WinningTeam      946 non-null    object
#  12  WonBy            950 non-null    object
#  13  Margin           932 non-null    float64
#  14  method           19 non-null     object
#  15  Player_of_Match  946 non-null    object
# ...
